# %%
from bs4 import BeautifulSoup
import requests
import re

url = 'https://www.wmrt.org.uk/incidents/upper-eskdale-sat-22nd-mar-2025/'

# %%
page_content = requests.get(url)
soup = BeautifulSoup(page_content.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <title>Upper Eskdale – Sat 22nd Mar 2025 – Wasdale Mountain Rescue</title>
# <meta content="max-image-preview:large" name="robots">
# <style>img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }</style>
# <link href="//fonts.googleapis.com" rel="dns-prefetch">
# <link href="https://www.wmrt.org.uk/feed/" rel="alternate" title="Wasdale Mountain Rescue » Feed" type="application/rss+xml"/>
# <style media="all" type="text/css">@font-face{font-family:'Roboto';font-display:block;font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v47/KFO7CnqEu92Fr1ME7kSn66aGLdTylUAMa3GUBHMdazTgWw.woff2) format('woff2');unicode-range:U+0460-052F,U+1C80-1C8A,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Roboto';font-display:block;font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v47/KFO7CnqEu92Fr1ME7kSn66aGLdTylUAMa3iUBHMdazTgWw.woff2) format('woff2');unicode-range:U+0301,U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:'Roboto';font-display:block;font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v47/KFO7CnqEu92Fr1ME7kSn66aGLdTylUAMa3CUBHMdazTgWw.woff2) format('woff2');unicode-range:U+1F00-1FFF}@font-face{font-family:'Roboto';font-display:block;font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v47/KFO7CnqEu92Fr1ME7kSn66aGLdTylUAMa3-UBHMdazTgWw.woff2) format('woff2');unicode-range:U+0370-0377,U+037A-037F,U+0384-038A,U+038C,U+038E-03A1,U+03A3-03FF}@font-face{font-family:'Roboto';font-display:block;font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v47/KFO7CnqEu92Fr1ME7kSn66aGLdTylUAMawCUBHMdazTgWw.woff2) format('woff2');unicode-range:U+0302-0303,U+0305,U+0307-0308,U+0310,U+0312,U+0315,U+031A,U+0326-0327,U+032C,U+032F-0330,U+0332-0333,U+0338,U+033A,U+0346,U+034D,U+0391-03A1,U+03A3-03A9,U+03B1-03C9,U+03D1,U+03D5-03D6,U+03F0-03F1,U+03F4-03F5,U+2016-2017,U+2034-2038,U+203C,U+2040,U+2043,U+2047,U+2050,U+2057,U+205F,U+2070-2071,U+2074-208E,U+2090-209C,U+20D0-20DC,U+20E1,U+20E5-20EF,U+2100-2112,U+2114-2115,U+2117-2121,U+2123-214F,U+2190,U+2192,U+2194-21AE,U+21B0-21E5,U+21F1-21F2,U+21F4-2211,U+2213-2214,U+2216-22FF,U+2308-230B,U+2310,U+2319,U+231C-2321,U+2336-237A,U+237C,U+2395,U+239B-23B7,U+23D0,U+23DC-23E1,U+2474-2475,U+25AF,U+25B3,U+25B7,U+25BD,U+25C1,U+25CA,U+25CC,U+25FB,U+266D-266F,U+27C0-27FF,U+2900-2AFF,U+2B0E-2B11,U+2B30-2B4C,U+2BFE,U+3030,U+FF5B,U+FF5D,U+1D400-1D7FF,U+1EE00-1EEFF}@font-face{font-family:'Roboto';font-display:block;font-style:normal;font-weight:300;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v47/KFO7CnqEu92Fr1ME7kSn66aGLdTylUAMaxKUBHMdazTgWw.woff2) format('woff2');unicode-range:U+0001-000C,U+000E-001F,U+007F-009F,U+20DD-20E0,U+20E2-20E4,U+2150-218F,U+2190,U+2192,U+2194-2199,U+21AF,U+21E6-21F0,U+21F3,U+2218-2219,U+2299,U+22C4-22C6,U+2300-243F,U+2440-244A,U+2460-24FF,U+25A0-27BF,U+2800-28FF,U+2921-2922,U+2981,U+29BF,U+29EB,U+2B00-2BFF,U+4DC0-4DFF,U+FFF9-FFFB,U+10140-1018E,U+10190-1019C,U+101A0,U+101D0-101FD,U+102E0-102FB,U+10E60-10E7E,U+1D2C0-1D2D3,U+1D2E0-1D37F,U+1F000-1F0FF,U+1F100-1F1AD,U+1F1E6-1F1FF,U+1F30D-1F30F,U+1F315,U+1F31C,U+1F31E,U+1F320-1F32C,U+1F336,U+1F378,U+1F37D,U+1F382,U+1F393-1F39F,U+1F3A7-1F3A8,U+1F3AC-1F3AF,U+1F3C2,U+1F3C4-1F3C6,U+1F3CA-1F3CE,U+1F3D4-1F3E0,U+1F3ED,U+1F3F1-1F3F3,U+1F3F5-1F3F7,U+1F408,U+1F415,U+1F41F,U+1F426,U+1F43F,U+1F441-1F442,U+1F444,U+1F446-1F449,U+1F44C-1F44E,U+1F453,U+1F46A,U+1F47D,U+1F4A3,U+1F4B0,U+1F4B3,U+1F4B9,U+1F4BB,U+1F4BF,U+1F4C8-1F4CB,U+1F4D6,U+1F4DA,U+1F4DF,U+1F4E3-1F4E6,U+1F4EA-1F4ED,U+1F4F7,U+1F4F9-1F4FB,U+1F4FD-1F4FE,U+1F503,U+1F507-1F50B,U+1F50D,U+1F512-1F513,U+1F53E-1F54A,U+1F54F-1F5FA,U+1F610,U+1F650-1F67F,U+1F687,U+1F68D,U+1F691,U+1F694,U+1F698,U+1F6AD,U+1F6B2,U+1F6B9-1F6BA,U+1F6BC,U+1F6C6-1F6CF,U+1F6D3-1F6D7,U+1F6E0-1F6EA,U+1F6F0-1F6F3,U+1F6F7-1F6FC,U+1F700-1F7FF,U+1F800-1F80B,U+1F810-1F847,U+1F850-1F859,U+1F860-1F887,U+1F890-1F8AD,U+1F8B0-1F8BB,U+1F8C0-1F8C1,U+1F900-1F90B,U+1F93B,U+1F946,U+1F984,U+1F996,U+1F9E9,U+1FA00-1FA6F,U+1FA70-1FA7C,U+1FA80-1FA89,U+1FA8F-1FAC6,U+1FACE-1FADC,U+1FADF-1FAE9,U+1FAF0-1FAF8,U+1FB00-1FBFF}@font-face{font-family:'Roboto';font-display:block;font-style:norma ...
# <style id="classic-theme-styles-inline-css" type="text/css">
# /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
# </style>
# <style id="global-styles-inline-css" type="text/css">
# :root{--wp--preset--aspect-ratio--square: 1;--wp--preset--aspect-ratio--4-3: 4/3;--wp--preset--aspect-ratio--3-4: 3/4;--wp--preset--aspect-ratio--3-2: 3/2;--wp--preset--aspect-ratio--2-3: 2/3;--wp--preset--aspect-ratio--16-9: 16/9;--wp--preset--aspect-ratio--9-16: 9/16;--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--color--accent: #e91e63;--wp--preset--color--background-color: #E5E5E5;--wp--preset--color--header-gradient: #a81d84;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:root :where(.is-layout-flow) > :first-child{margin-block-start: 0;}:root :where(.is-layout-flow) > :last-child{margin-block-end: 0;}:root :where(.is-layout-flow) > *{margin-block-start: 24px;margin-block-end: 0;}:root :where(.is-layout-constrained) > :first-child{margin-block-start: 0;}:root :where(.is-layout-constrained) > :last-child{margin-block-end: 0;}:root :where(.is-layout-constrained) > *{margin-block-start: 24px;margin-block-end: 0;}:root :where(.is-layout-flex){gap: 24px;}:root :where(.is-layout-grid){gap: 24px;}body .is-layout-flex{display: flex;}.is-layout-flex{flex-wrap: wrap;align-items: center;}.is-layout-flex > :is(*, div){margin: 0;}body .is-layout-grid{display: grid;}.is-layout-grid > :is(*, div){margin: 0;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-c ...
# :root :where(.wp-block-pullquote){font-size: 1.5em;line-height: 1.6;}
# </style>
# <link href="https://www.wmrt.org.uk/wp-content/cache/wpo-minify/1741724414/assets/wpo-minify-header-ced5478e.min.css" id="wpo_min-header-0-css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 8]>
# <link rel='stylesheet' id='ccchildpagesiecss-css' href='https://www.wmrt.org.uk/wp-content/plugins/cc-child-pages/includes/css/styles.ie.css' type='text/css' media='all' />
# <![endif]-->
# <link href="https://www.wmrt.org.uk/wp-content/cache/wpo-minify/1741724414/assets/wpo-minify-header-540333e4.min.css" id="wpo_min-header-2-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="wpo_min-header-0-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var mobilebanner_opts = {"bgcolour":"#DD1C1C","textcolour":"white","text":"Donate Now","url":"https:\/\/link.justgiving.com\/v1\/charity\/donate\/charityId\/80802?amount=50.00&currency=GBP&reference=MobileMenuBtn","width":"768","height":"0","directory":"https:\/\/www.wmrt.org.uk\/wp-content\/plugins\/mobile-banner\/public\/","closebutton":"0","cookiedays":"","newtab":"0"};
# /* ]]> */
# </script>
# <script defer="" id="wpo_min-header-0-js" src="https://www.wmrt.org.uk/wp-content/cache/wpo-minify/1741724414/assets/wpo-minify-header-53f0190b.min.js" type="text/javascript"></script>
# <link href="https://www.wmrt.org.uk/incidents/upper-eskdale-sat-22nd-mar-2025/" rel="canonical"/>
# <link href="https://www.wmrt.org.uk/?p=20615" rel="shortlink"/>
# <link href="https://www.wmrt.org.uk/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.wmrt.org.uk%2Fincidents%2Fupper-eskdale-sat-22nd-mar-2025%2F" rel="alternate" title="oEmbed (JSON)" type="application/json+oembed"/>
# <link href="https://www.wmrt.org.uk/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.wmrt.org.uk%2Fincidents%2Fupper-eskdale-sat-22nd-mar-2025%2F&amp;format=xml" rel="alternate" title="oEmbed (XML)" type="text/xml+oembed"/>
# <link href="https://www.wmrt.org.uk/wp-content/plugins/wmrt/images/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://www.wmrt.org.uk/wp-content/plugins/wmrt/images/favicon-32x32.png/" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://www.wmrt.org.uk/wp-content/plugins/wmrt/images/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://www.wmrt.org.uk/wp-content/plugins/wmrt/images/site.webmanifest" rel="manifest"/>
# <link color="#da532c" href="https://www.wmrt.org.uk/wp-content/plugins/wmrt/images/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="https://www.wmrt.org.uk/wp-content/plugins/wmrt/images/favicon.ico" rel="shortcut icon"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="https://www.wmrt.org.uk/wp-content/plugins/wmrt/images/browserconfig.xml" name="msapplication-config"/>
# <meta content="#ffffff" name="theme-color"/><meta content="telephone=no" name="format-detection"><meta content="D_xkkXf94gF-i3Or-y_qlRYtOJR6gFs55jbQL66o-us" name="google-site-verification"><!-- Enter your scripts here --><link href="https://www.wmrt.org.uk/wp-content/uploads/2019/05/logo-login-150x150.gif" rel="icon" sizes="32x32">
# <link href="https://www.wmrt.org.uk/wp-content/uploads/2019/05/logo-login.gif" rel="icon" sizes="192x192">
# <link href="https://www.wmrt.org.uk/wp-content/uploads/2019/05/logo-login.gif" rel="apple-touch-icon">
# <meta content="https://www.wmrt.org.uk/wp-content/uploads/2019/05/logo-login.gif" name="msapplication-TileImage">
# <style id="wp-custom-css" type="text/css">
# 			#singlemap, #viewDiv {
# 	height:550px;
# 	border-radius: 6px;
# 	-webkit-box-shadow: 0 16px 38px -12px rgba(0, 0, 0, 0.56), 0 4px 25px 0 rgba(0, 0, 0, 0.12), 0 8px 10px -5px rgba(0, 0, 0, 0.2);
# box-shadow: 0 16px 38px -12px rgba(0, 0, 0, 0.56), 0 4px 25px 0 rgba(0, 0, 0, 0.12), 0 8px 10px -5px rgba(0, 0, 0, 0.2);
# position:relative;
# }
# div.entry-categories{display:none;}
# dl dd {margin-bottom:0;}
# h4.author{display:none}
#
# .olMap, .olMapViewport {
#     border-radius: 6px;
# }
# .posted-by{display:none;}
# .related-posts{display:none;}
# a.navbar-brand>p:before{
# 	background-image: url(https://www.wmrt.org.uk/wp-content/plugins/wmrt/images/logo-login.gif);
# 	height: 45px !important;
# 	width: 45px !important;
# 	background-size: 45px 45px !important;
# 	display:block;
# 	float: left;
# 	margin: -10px 10px 0 0;
# 	content: " ";
# }
# ul.nav li.btn a {
# 	padding-left: 5px; padding-right: 5px;
# }
#
# .ptam-block-post-grid-image {
# 	border: none !important;
#     border-radius: 6px;
#     -webkit-box-shadow: 0 16px 38px -12px rgba(0, 0, 0, 0.56), 0 4px 25px 0 rgba(0, 0, 0, 0.12), 0 8px 10px -5px rgba(0, 0, 0, 0.2);
#     box-shadow: 0 16px 38px -12px rgba(0, 0, 0, 0.56), 0 4px 25px 0 rgba(0, 0, 0, 0.12), 0 8px 10px -5px rgba(0, 0, 0, 0.2);
# }
# img.size-ptam-block-post-grid-square:hover {
# -webkit-transform: scale3d(1.1, 1.1, 1);
# transform: scale3d(1.1, 1.1, 1);
# }
# img.size-ptam-block-post-grid-square {
# transition: 1s ease-out;
# }
# .ptam-block-post-grid-image {
# 	overflow: hidden;
# 	position:relative;
#   z-index:1;
# }
# .os-api-branding.logo {margin:8px}
# .home .ptam-block-post-grid .ptam-block-post-grid-image img {width:550px;}
# .home .ptam-block-post-grid .ptam-block-post-grid-image {
# 	display: grid;
#   place-content: center;
# 	max-height: 450px;
# }
#
# /*-- Popup Styles */
#   /* Overlay with blur */
#   #customPopup .popup-overlay {
#     position: fixed;
#     top: 0;
#     left: 0;
#     width: 100%;
#     height: 100%;
#     backdrop-filter: blur(8px);
#     background-color: rgba(0, 0, 0, 0.2);
#     z-index: 9998;
#   }
#
#   /* Popup box */
#   #customPopup .popup-content {
#     position: fixed;
#     top: 50%;
#     left: 50%;
#     transform: translate(-50%, -50%);
#     background: rgba(255, 255, 255, 0.9);
#     padding: 2rem;
#     border-radius: 12px;
#     box-shadow: 0 8px 30px rgba(0, 0, 0, 0.2);
#     z-index: 9999;
#     max-width: 400px;
#     width: 90%;
#     font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#     text-align: center;
#     backdrop-filter: saturate(180%) blur(10px);
#     box-sizing: border-box;
#   }
#
#   /* Close button */
#   #customPopup .close-btn {
#     position: absolute;
#     top: 12px;
#     right: 16px;
#     font-size: 24px;
#     background: none;
#     border: none;
#     color: #666;
#     cursor: pointer;
#     transition: color 0.2s ease;
# 		padding: 0px 13px;
#     margin: 0 0 0 0;
#   }
#
#   #customPopup .close-btn:hover {
#     color: #000;
#   }
#
#   /* CTA button */
#   .popup-cta {
#     display: inline-block;
#     margin-top: 1.5rem;
#     padding: 0.75rem 1.5rem;
#     background-color: #e63946;
#     color: #fff;
#     text-decoration: none;
#     font-weight: 600;
#     border-radius: 6px;
#     transition: background-color 0.2s ease;
#   }
#
#   .popup-cta:hover {
#     background-color: #d62828;
#   }
#
#   /* Responsive tweaks */
#   @media (max-width: 480px) {
#     #customPopup .popup-content {
#       padding: 1.5rem;
#       font-size: 1rem;
#     }
#
#     .popup-cta {
#       width: 100%;
#       padding: 0.75rem;
#     }
#   }		</style>
# </meta></link></link></link></meta></meta></link></meta></head>
# <body class="incidents-template-default single single-incidents postid-20615 blog-post header-layout-default">
# <div class="wrapper post-20615 incidents type-incidents status-publish has-post-thumbnail hentry incident-type-alert incident-weather-dry incident-weather-sunny cause-cragfast location-upper-eskdale agencies-cumbria-police incident-tags-cragfast default">
# <header class="header">
# <div style="display: none"></div> <nav class="navbar navbar-default hestia_left navbar-not-transparent navbar-fixed-top">
# <div class="container">
# <div class="navbar-header">
# <div class="title-logo-wrapper">
# <a class="navbar-brand" href="https://www.wmrt.org.uk/" title="Wasdale Mountain Rescue">
# <p>Wasdale Mountain Rescue</p></a>
# </div>
# <div class="navbar-toggle-wrapper">
# <button class="navbar-toggle" data-target="#main-navigation" data-toggle="collapse" type="button">
# <span class="icon-bar"></span><span class="icon-bar"></span><span class="icon-bar"></span> <span class="sr-only">Toggle Navigation</span>
# </button>
# </div>
# </div>
# <div class="collapse navbar-collapse" id="main-navigation"><ul class="nav navbar-nav" id="menu-main-menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1705" id="menu-item-1705"><a href="/incidents/" title="Incidents">Incidents</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current_page_parent menu-item-15853" id="menu-item-15853"><a href="https://www.wmrt.org.uk/news/" title="News">News</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-16470 dropdown" id="menu-item-16470"><a class="dropdown-toggle" href="#" title="Advice">Advice <span class="caret-wrap"><span class="caret"><svg aria-hidden="true" class="svg-inline--fa fa-chevron-down fa-w-14" data-icon="chevron-down" data-prefix="fas" focusable="false" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"><path d="M207.029 381.476L12.686 187.132c-9.373-9.373-9.373-24.569 0-33.941l22.667-22.667c9.357-9.357 24.522-9.375 33.901-.04L224 284.505l154.745-154.021c9.379-9.335 24.544-9.317 33.901.04l22.667 22.667c9.373 9.373 9.373 24.569 0 33.941L240.971 381.476c-9.373 9.372-24.569 9.372-33.942 0z"></path></svg></span></span></a>
# <ul class="dropdown-menu" role="menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-16355" id="menu-item-16355"><a href="http://www.adventuresmart.uk" title="Adventure Smart">Adventure Smart</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1318" id="menu-item-1318"><a href="https://www.wmrt.org.uk/the-easiest-way-up-scafell-pike/" title="Climbing Scafell Pike">Climbing Scafell Pike</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-10644" id="menu-item-10644"><a href="https://www.wmrt.org.uk/the-three-peaks/" title="The National Three Peaks">The National Three Peaks</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-825" id="menu-item-825"><a href="https://www.wmrt.org.uk/preparation-for-going-into-the-fells/" title="Preparation">Preparation</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-755" id="menu-item-755"><a href="https://www.wmrt.org.uk/advice/weather/" title="Weather Forecasts">Weather Forecasts</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-1042 dropdown dropdown-submenu" id="menu-item-1042"><a class="dropdown-toggle" href="https://www.wmrt.org.uk/advice/accident-black-spots/" title="Accident Black Spots">Accident Black Spots <span class="caret-wrap"><span class="caret"><svg aria-hidden="true" class="svg-inline--fa fa-chevron-down fa-w-14" data-icon="chevron-down" data-prefix="fas" focusable="false" role="img" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"><path d="M207.029 381.476L12.686 187.132c-9.373-9.373-9.373-24.569 0-33.941l22.667-22.667c9.357-9.357 24.522-9.375 33.901-.04L224 284.505l154.745-154.021c9.379-9.335 24.544-9.317 33.901.04l22.667 22.667c9.373 9.373 9.373 24.569 0 33.941L240.971 381.476c-9.373 9.372-24.569 9.372-33.942 0z"></path></svg></span></span></a>
# <ul class="dropdown-menu" role="menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1041" id="menu-item-1041"><a href="https://www.wmrt.org.uk/scafell-broad-stand/" title="Broad Stand Ã¢â‚¬â€œ Scafell">Broad Stand Ã¢â‚¬â€œ Scafell</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1040" id="menu-item-1040"><a href="https://www.wmrt.org.uk/piers-gill-scafell-pike/" title="Piers Gill Ã¢â‚¬â€œ Scafell Pike">Piers Gill Ã¢â‚¬â€œ Scafell Pike</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-10522" id="menu-item-10522"><a href="https://www.wmrt.org.uk/advice/accident-black-spots/wasdale-screes/" title="Wasdale Screes">Wasdale Screes</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2080" id="menu-item-2080"><a href="https://www.wmrt.org.uk/donate-to-the-team/" title="Support Us">Support Us</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18573" id="menu-item-18573"><a href="https://www.wmrt.org.uk/team-shop/" title="Buy Team Merchandise">Buy Team Merchandise</a></li>
# <li class="btn btn-secondary menu-item menu-item-type-post_type menu-item-object-page menu-item-13887" id="menu-item-13887"><a href="https://www.wmrt.org.uk/how-to-join-the-team/" title="Join Our Team">Join Our Team</a></li>
# <li class="btn btn-primary menu-item menu-item-type-custom menu-item-object-custom menu-item-15821" id="menu-item-15821"><a href="https://link.justgiving.com/v1/charity/donate/charityId/80802?amount=50.00&amp;currency=GBP&amp;reference=MenuBtn" title="Donate">Donate</a></li>
# </ul></div> </div>
# </nav>
# </header>
# <div class="boxed-layout-header page-header header-small" data-parallax="active" id="primary"><div class="container"><div class="row"><div class="col-md-10 col-md-offset-1 text-center"><h1 class="hestia-title entry-title">Upper Eskdale – Sat 22nd Mar 2025</h1><h4 class="author">Published by <a class="vcard author" href="https://www.wmrt.org.uk/author/bamforthj/"><strong class="fn">John Bamforth</strong></a> on <time class="entry-date published" content="2025-04-02" datetime="2025-04-02T15:13:18+01:00">Wed 2nd Apr 2025</time></h4></div></div></div><div class="header-filter" style="background-image: url(https://www.wmrt.org.uk/wp-content/uploads/2025/03/22-1.jpg);"></div></div>
# <div class="main main-raised">
# <div class="blog-post blog-post-wrapper">
# <div class="container">
# <article class="section section-text" id="post-20615">
# <div class="row">
# <div class="col-md-8 single-post-container col-md-offset-2" data-layout="sidebar-right">
# <div class="single-post-wrap entry-content">
# <dl class="dl-horizontal">
# <dt>Incident</dt><dd>25 in 2025</dd>
# <dt>Type</dt><dd><a href="https://www.wmrt.org.uk/incident-type/alert/" rel="tag">Alert</a> — <a href="https://www.wmrt.org.uk/incidents/causes/cragfast/" rel="tag">Cragfast</a></dd>
# <dt>Location</dt><dd><a href="https://www.wmrt.org.uk/incidents/locations/upper-eskdale/">Upper Eskdale</a></dd><dt>Weather</dt><dd><a href="https://www.wmrt.org.uk/incidents/weather/dry/" rel="tag">Dry</a>, <a href="https://www.wmrt.org.uk/incidents/weather/sunny/" rel="tag">Sunny</a></dd><dt>Other Agencies</dt><dd><a href="https://www.wmrt.org.uk/incidents/agencies/cumbria-police/" rel="tag">Cumbria Police</a></dd><dt>Tagged</dt><dd><a href="https://www.wmrt.org.uk/incident-tags/cragfast/" rel="tag">Cragfast</a></dd></dl><div class="x11i5rnm xat24cr x1mh8g0r x1vvkbs xtlvy1s x126k92a">
# <div dir="auto">A short alert when a call was received from Cumbria Police about a walker who was concerned for his safety, having been separated from his walking party and was on ground with loose rock.</div>
# </div>
# <div class="x11i5rnm xat24cr x1mh8g0r x1vvkbs xtlvy1s x126k92a">
# <div dir="auto">However, after a few minutes a further call was received that the party had reunited and the walker was back on safe ground. The team was stood down.</div>
# </div>
# <div class="x11i5rnm xat24cr x1mh8g0r x1vvkbs xtlvy1s x126k92a">
# <div dir="auto"><span class="html-span xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x1hl2dhg x16tdsg8 x1vvkbs"><a attributionsrc="/privacy_sandbox/comet/register/source/?xt=AZWMcvPVwC5RTSVCNEZloKyGFUyAh19GW5z2KZt1RVm-wj1d0KZ6SEkoG7ltw1U_VULptQekaW2oj0nWADl9bAdy8xsA9SpTd9u4Zq8NgfQUgE3JBJA1C35Zo0xgUNi2zY6fhCG8664wyyvgDxCLksmD_8uqDqqK68p5Y09XP1RvLCu4bVrMPF37bGjMrNIck9PQ1dFMlMsgbMYJ51B76UqdNFHjz5gtmhmWUBR_W8Qa0z_mPhWHZwsxW5WaIfgIOHdLTuhzCOek0O4nmB3cS03GPbH1O8QZnTb9CcqH1VTgsQUaue3OSvN7udkfyuAcLFGqoI0zNJHRmM0SsLjkkPQf6B3X3xjQdo6lbUKQQe4HLSL67MtUxAkYmUaiTxwhuDe7SQypjl19_POVg6AMmLu_y962_8hFDwaoEy2te5ubcBwwXoip1IFUWDF_SelUaC1ZHi_rTlA5feuQzy2gPAuc03He1QJVXEz1sZr1do_ofyBA7r2v5feV-8cxgY95QuZQeh6J0BtA1EAHI-l1gaOQFsHjKLT6D_3wluWxG_jhfI1eJt0JgUKSxP7prUgiWARqqKzwdicX7nH1CF8m9za9OfEKisADgwM4-932X06Lu6GZpp2XOcv29dX29wkFEw_aHVY7YOIu8eguY5CjB99Y52EzY8I5ECDdPTqX9XmZNn4UEYqTVwBfq9BywPQdgtGRPOkTqRQKCiSd_T9SPGv1tYP81WauVwf7EQtoQGRef6xSXGTX7NFLG3GSvpXdEdp8smnaxMK9q8SaJRQfKIO9RvLeoA-IlAkoMVhDEc1oQHx29yDWFyszG2P1O6Ie4Vsf_8B1W9nIbt8hZg4tJo1TqWr0bHhJotQJXaZs0q6jqzMCN8ggpr3E-2wvx9Xy39MwdtXlm1dvAZSr7QZ12w0v-fGGd01E-2yWw9Bwmz23301AC7ONIfP3HlU_vkfAP-prAv27y1RHRaPdyJbZzHoBaPmRVvqC4F5hbJE0RvogJkHrYvSPYk4IzNJftRIHaEgXFXciEQz78DyXVzP-Vu7qIyZtM7YNChT9JFIkNwk2cfcxcAnj_XWlARExbAcyJrN-8zloLYzmI0qVakgQnLTY_3x2_2-gDk5sHt6AP8n-J2OCLYkkHLL69xBrCUJMzrrf5HqAVgxmsm7PbWbZ_xUFs404Jb6IeMnvipa681IglanTnN9NnJrBr9UI26oQclaOtuz2qvnAdtrn25_7-1bzhlcU4HRKMF5-OLXjuc7Ewl0B9yeERMY3OXOUmP2ChysdW-J2r7RKotCA-4UVsqojKzcOtwquVW1FgJ1o_hsHrKj9MEgmSuLQswe6n_gUy7o9Ey3FKn5K-qPRFiyRD2jh" class="x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz xkrqix3 x1sur9pj x1fey0fg x1s688f" href="https://www.adventuresmart.uk/" rel="nofollow noopener" role="link" tabindex="0" target="_blank">https://www.adventuresmart.uk/</a></span></div>
# </div>
# <div class="x11i5rnm xat24cr x1mh8g0r x1vvkbs xtlvy1s x126k92a">
# <div dir="auto"><span class="html-span xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x1hl2dhg x16tdsg8 x1vvkbs"><a attributionsrc="/privacy_sandbox/comet/register/source/?xt=AZWMcvPVwC5RTSVCNEZloKyGFUyAh19GW5z2KZt1RVm-wj1d0KZ6SEkoG7ltw1U_VULptQekaW2oj0nWADl9bAdy8xsA9SpTd9u4Zq8NgfQUgE3JBJA1C35Zo0xgUNi2zY6fhCG8664wyyvgDxCLksmD_8uqDqqK68p5Y09XP1RvLCu4bVrMPF37bGjMrNIck9PQ1dFMlMsgbMYJ51B76UqdNFHjz5gtmhmWUBR_W8Qa0z_mPhWHZwsxW5WaIfgIOHdLTuhzCOek0O4nmB3cS03GPbH1O8QZnTb9CcqH1VTgsQUaue3OSvN7udkfyuAcLFGqoI0zNJHRmM0SsLjkkPQf6B3X3xjQdo6lbUKQQe4HLSL67MtUxAkYmUaiTxwhuDe7SQypjl19_POVg6AMmLu_y962_8hFDwaoEy2te5ubcBwwXoip1IFUWDF_SelUaC1ZHi_rTlA5feuQzy2gPAuc03He1QJVXEz1sZr1do_ofyBA7r2v5feV-8cxgY95QuZQeh6J0BtA1EAHI-l1gaOQFsHjKLT6D_3wluWxG_jhfI1eJt0JgUKSxP7prUgiWARqqKzwdicX7nH1CF8m9za9OfEKisADgwM4-932X06Lu6GZpp2XOcv29dX29wkFEw_aHVY7YOIu8eguY5CjB99Y52EzY8I5ECDdPTqX9XmZNn4UEYqTVwBfq9BywPQdgtGRPOkTqRQKCiSd_T9SPGv1tYP81WauVwf7EQtoQGRef6xSXGTX7NFLG3GSvpXdEdp8smnaxMK9q8SaJRQfKIO9RvLeoA-IlAkoMVhDEc1oQHx29yDWFyszG2P1O6Ie4Vsf_8B1W9nIbt8hZg4tJo1TqWr0bHhJotQJXaZs0q6jqzMCN8ggpr3E-2wvx9Xy39MwdtXlm1dvAZSr7QZ12w0v-fGGd01E-2yWw9Bwmz23301AC7ONIfP3HlU_vkfAP-prAv27y1RHRaPdyJbZzHoBaPmRVvqC4F5hbJE0RvogJkHrYvSPYk4IzNJftRIHaEgXFXciEQz78DyXVzP-Vu7qIyZtM7YNChT9JFIkNwk2cfcxcAnj_XWlARExbAcyJrN-8zloLYzmI0qVakgQnLTY_3x2_2-gDk5sHt6AP8n-J2OCLYkkHLL69xBrCUJMzrrf5HqAVgxmsm7PbWbZ_xUFs404Jb6IeMnvipa681IglanTnN9NnJrBr9UI26oQclaOtuz2qvnAdtrn25_7-1bzhlcU4HRKMF5-OLXjuc7Ewl0B9yeERMY3OXOUmP2ChysdW-J2r7RKotCA-4UVsqojKzcOtwquVW1FgJ1o_hsHrKj9MEgmSuLQswe6n_gUy7o9Ey3FKn5K-qPRFiyRD2jh" class="x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz xkrqix3 x1sur9pj x1fey0fg x1s688f" href="https://www.facebook.com/hashtag/beadventuresmart?__eep__=6&amp;__cft__[0]=AZV4S3DIcDw8cga7tQaDZj_AIqKgnxP2Vx1bCp5tUlwTjm2LNULeUwQ2NkksBREZAJsZl5pNgScMRhvste5p3kt5wJWpLzAthgEmcZNkZqs5FP9DleNFTe0477DJXdrzHxnbCN8SrtXhXu049ZIhzg9E4n7kMyFKdO6_CZSLUbOHkopHbpZ_Bl7KyKhxkSFbKEk&amp;__tn__=*NK-R" rel="noopener" role="link" tabindex="0" target="_blank">#BeAdventureSmart</a></span> and make a good day better.</div>
# </div>
# <div class="x11i5rnm xat24cr x1mh8g0r x1vvkbs xtlvy1s x126k92a">
# <div dir="auto">Ask yourself three questions before you set off:</div>
# <div dir="auto">1. Do I have the right GEAR ?</div>
# <div dir="auto">2. Do I know what the WEATHER will be like?</div>
# <div dir="auto">3. Am I confident that I have the KNOWLEDGE &amp; SKILLS for the day?</div>
# <div dir="auto">
# <style type="text/css">
# 			#gallery-2 {
# 				margin: auto;
# 			}
# 			#gallery-2 .gallery-item {
# 				float: left;
# 				margin-top: 10px;
# 				text-align: center;
# 				width: 100%;
# 			}
# 			#gallery-2 img {
# 				border: 2px solid #cfcfcf;
# 			}
# 			#gallery-2 .gallery-caption {
# 				margin-left: 0;
# 			}
# 			/* see gallery_shortcode() in wp-includes/media.php */
# 		</style>
# <div class="gallery galleryid-20615 gallery-columns-1 gallery-size-full" id="gallery-2"><dl class="gallery-item">
# <dt class="gallery-icon landscape">
# <a href="https://www.wmrt.org.uk/wp-content/uploads/2025/03/22-1.jpg" rel="lightbox[20615]"><img alt="" class="attachment-full size-full" decoding="async" fetchpriority="high" height="261" sizes="(max-width: 500px) 100vw, 500px" src="https://www.wmrt.org.uk/wp-content/uploads/2025/03/22-1.jpg" srcset="https://www.wmrt.org.uk/wp-content/uploads/2025/03/22-1.jpg 500w, https://www.wmrt.org.uk/wp-content/uploads/2025/03/22-1-400x209.jpg 400w" width="500"/></a>
# </dt></dl><br style="clear: both"/>
# </div>
# </div>
# </div>
# <link href="https://labs.os.uk/public/os-api-branding/v0.2.0/os-api-branding.css" rel="stylesheet">
# <link href="https://cdn.jsdelivr.net/gh/openlayers/openlayers.github.io@master/en/v6.5.0/css/ol.css" rel="stylesheet">
# <div id="mapcontainer-outside">
# <div id="mapcontainer-inside">
# <div id="viewDiv"></div>
# </div>
# <div id="maplink"><a href="/heatmap2.htm">See a map of all incidents</a></div>
# </div>
# <script data-div="viewDiv" src="https://labs.os.uk/public/os-api-branding/v0.2.0/os-api-branding.js"></script>
# <script src="https://cdn.jsdelivr.net/gh/openlayers/openlayers.github.io@master/en/v6.5.0/build/ol.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/proj4js/2.5.0/proj4.js"></script>
# <script>
#
# defineGetDataExtent = function () {
#   OpenLayers.Layer.Markers.prototype.getDataExtent=function() {
#     var maxExtent=null;
#     if(this.markers&&(this.markers.length>0)){
#       var maxExtent=new OpenSpace.MapBounds();
#       for(var i=0,len=this.markers.length;i<len;i++){
#         var marker=this.markers[i];
#         maxExtent.extend(marker.lonlat);
#       }
#     }
#     return maxExtent;
#   }
# }
#
# function NGR2NE(ngr){
# var e;
# var n;
#
# ngr = ngr.toUpperCase(ngr);
#
# //remove any spaces
# var bits = ngr.split(' ');
# ngr = '';
# for(var i=0;i<bits.length;i++)
#   ngr+=bits[i];
#
# var c = ngr.charAt(0);
# if (c =='S'){
#   e = 0;
#   n = 0;
#   }
# else if (c == 'T'){
#   e = 500000;
#   n = 0;
#   }
# else if (c == 'N'){
#   n = 500000;
#   e = 0;
#   }
# else if (c == 'O'){
#   n = 500000;
#   e = 500000;
#   }
# else if(c == 'H'){
#   n = 1000000;
#   e = 0;
#   }
# else
#   return null;
#
# c = ngr.charAt(1);
# if(c == 'I')
#   return null;
#
# c = ngr.charCodeAt(1) - 65;
# if(c > 8)
#   c -= 1;
# e += (c % 5) * 100000;
# n += (4 - Math.floor(c/5)) * 100000;
#
# c = ngr.substr(2);
# if ((c.length%2) == 1)
#   return null;
# if (c.length > 10)
#   return null;
#
# try{
#   var s = c.substr(0,c.length/2);
#   while(s.length < 5)
#       s += '0';
#   e += parseInt(s,10);
#   if(isNaN(e))
#       return null;
#
#   s = c.substr(c.length/2);
#   while(s.length < 5)
#       s += '0';
#   n += parseInt(s,10);
#   if(isNaN(n))
#       return null;
#
#   return [e,n];
# }
# catch (ex)
# {
#   return null;
# }
#
# }
#
#     var apiKey = 'ypVSkOBlRwllXjgPGPq2aTGnwvy8aTUr';
#
#     var serviceUrl = 'https://api.os.uk/maps/raster/v1/zxy';
#
#     // Setup the EPSG:27700 (British National Grid) projection.
#     proj4.defs('EPSG:27700', '+proj=tmerc +lat_0=49 +lon_0=-2 +k=0.9996012717 +x_0=400000 +y_0=-100000 +ellps=airy +towgs84=446.448,-125.157,542.06,0.15,0.247,0.842,-20.489 +units=m +no_defs');
#     ol.proj.proj4.register(proj4);
#
#     var tilegrid = new ol.tilegrid.TileGrid({
#         resolutions: [ 896.0, 448.0, 224.0, 112.0, 56.0, 28.0, 14.0, 7.0, 3.5, 1.75 ],
#         origin: [ -238375.0, 1376256.0 ]
#     });
#
#     var pos = NGR2NE ('NY 215027');
#     // Initialize the map object.
#     var map = new ol.Map({
#         layers: [
#             new ol.layer.Tile({
#                 source: new ol.source.XYZ({
#                     url: serviceUrl + '/Leisure_27700/{z}/{x}/{y}.png?key=' + apiKey,
#                     projection: 'EPSG:27700',
#                     tileGrid: tilegrid
#                 })
#             })
#         ],
#         target: 'viewDiv',
#         view: new ol.View({
#             projection: 'EPSG:27700',
#             extent: [ -238375.0, 0.0, 900000.0, 1376256.0 ],
#             resolutions: tilegrid.getResolutions(),
#             minZoom: 0,
#             maxZoom: 9,
#             center: pos,
#             zoom: 7
#         })
#     });
#
#     var marker = new ol.layer.Vector({
#       source: new ol.source.Vector({
#           features: [
#               new ol.Feature({
#                   geometry: new ol.geom.Point(pos)
#               })
#           ]
#       }),
#       style: new ol.style.Style({
#           image: new ol.style.Icon({
#               src: 'https://www.wmrt.org.uk/wp-content/plugins/wmrt/images/marker-red.svg',
#               scale: 0.75,
#               anchor: [0.5, 1]
#           })
#       })
#   });
#   map.addLayer(marker);
#
# </script>
# <div id="rescueinfo"><p> Incident started at <strong>14:59</strong> and ended at <strong>15:17</strong> making <strong>0.3</strong> hrs in total. There was <strong>1</strong> Wasdale team member involved and the incident occured at <strong>NY 215027</strong>. Total rescuer hours: <strong>0.3</strong></p></div></link></link></div>
# <div class="section section-blog-info">
# <div class="row">
# <div class="col-md-6">
# <div class="entry-categories">Categories:											</div>
# </div>
# <div class="col-md-6">
# <div class="entry-social">
# <a class="btn btn-just-icon btn-round btn-facebook" data-original-title="Share on Facebook" href="https://www.facebook.com/sharer.php?u=https://www.wmrt.org.uk/incidents/upper-eskdale-sat-22nd-mar-2025/" rel="tooltip" target="_blank">
# <svg height="17" viewbox="0 0 320 512" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M279.14 288l14.22-92.66h-88.91v-60.13c0-25.35 12.42-50.06 52.24-50.06h40.42V6.26S260.43 0 225.36 0c-73.22 0-121.08 44.38-121.08 124.72v70.62H22.89V288h81.39v224h100.17V288z" fill="currentColor"></path></svg>
# </a>
# <a class="btn btn-just-icon btn-round btn-twitter" data-original-title="Share on X" href="https://x.com/share?url=https://www.wmrt.org.uk/incidents/upper-eskdale-sat-22nd-mar-2025/&amp;text=Upper%20Eskdale%20%E2%80%93%20Sat%2022nd%20Mar%202025" rel="tooltip" target="_blank">
# <svg fill="none" height="17" viewbox="0 0 1200 1227" width="20" xmlns="http://www.w3.org/2000/svg">
# <path d="M714.163 519.284L1160.89 0H1055.03L667.137 450.887L357.328 0H0L468.492 681.821L0 1226.37H105.866L515.491 750.218L842.672 1226.37H1200L714.137 519.284H714.163ZM569.165 687.828L521.697 619.934L144.011 79.6944H306.615L611.412 515.685L658.88 583.579L1055.08 1150.3H892.476L569.165 687.854V687.828Z" fill="#FFFFFF"></path>
# </svg>
# </a>
# <a class="btn btn-just-icon btn-round" data-original-title=" Share on Email" href="mailto:?subject=Upper%20Eskdale%20%26#8211;%20Sat%2022nd%20Mar%202025&amp;body=https://www.wmrt.org.uk/incidents/upper-eskdale-sat-22nd-mar-2025/" rel="tooltip">
# <svg height="17" viewbox="0 0 512 512" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M502.3 190.8c3.9-3.1 9.7-.2 9.7 4.7V400c0 26.5-21.5 48-48 48H48c-26.5 0-48-21.5-48-48V195.6c0-5 5.7-7.8 9.7-4.7 22.4 17.4 52.1 39.5 154.1 113.6 21.1 15.4 56.7 47.8 92.2 47.6 35.7.3 72-32.8 92.3-47.6 102-74.1 131.6-96.3 154-113.7zM256 320c23.2.4 56.6-29.2 73.4-41.4 132.7-96.3 142.8-104.7 173.4-128.7 5.8-4.5 9.2-11.5 9.2-18.9v-19c0-26.5-21.5-48-48-48H48C21.5 64 0 85.5 0 112v19c0 7.4 3.4 14.3 9.2 18.9 30.6 23.9 40.7 32.4 173.4 128.7 16.8 12.2 50.2 41.8 73.4 41.4z" fill="currentColor"></path></svg>
# </a>
# </div>
# </div> </div>
# <hr/>
# </div>
# </div> </div>
# </article>
# </div>
# </div>
# </div>
# <div class="section related-posts">
# <div class="container">
# <div class="row">
# <div class="col-md-12">
# <h2 class="hestia-title text-center">Related Posts</h2>
# <div class="row">
# <div class="col-md-4">
# <div class="card card-blog">
# <div class="content">
# <span class="category text-info"><a href="https://www.wmrt.org.uk/category/fundraising/" title="View all posts in Fundraising">Fundraising</a> </span>
# <h4 class="card-title">
# <a class="blog-item-title-link" href="https://www.wmrt.org.uk/2025/03/come-to-the-rescue-family-fun-day-with-your-local-heroes-10th-may/" rel="bookmark" title="COME TO THE RESCUE! – Family Fun Day with Your Local Heroes | 10th May">
# 														COME TO THE RESCUE! – Family Fun Day with Your Local Heroes | 10th May													</a>
# </h4>
# <p class="card-description">Incident25 in 2025 TypeAlert — Cragfast LocationUpper EskdaleWeatherDry, SunnyOther AgenciesCumbria PoliceTaggedCragfast COME TO THE RESCUE!! …Family Fun Day with Your Local Heroes… Hosted by Wasdale Mountain Rescue Team and Wasdale Head Inn 📅 10th May<a class="moretag" href="https://www.wmrt.org.uk/2025/03/come-to-the-rescue-family-fun-day-with-your-local-heroes-10th-may/"> Read more…</a></p>
# </div>
# </div>
# </div>
# <div class="col-md-4">
# <div class="card card-blog">
# <div class="card-image">
# <a href="https://www.wmrt.org.uk/2025/02/save-the-date-saturday-10-may-2025-the-wasdale-head-inn-supporting-wmrt/" title="Save the date – Saturday 10 May 2025 – The Wasdale Head Inn supporting WMRT">
# <img alt="" class="attachment-hestia-blog size-hestia-blog wp-post-image" decoding="async" height="240" loading="lazy" sizes="auto, (max-width: 360px) 100vw, 360px" src="https://www.wmrt.org.uk/wp-content/uploads/2025/02/Save-The-Date-360x240.jpg" srcset="https://www.wmrt.org.uk/wp-content/uploads/2025/02/Save-The-Date-360x240.jpg 360w, https://www.wmrt.org.uk/wp-content/uploads/2025/02/Save-The-Date-600x400.jpg 600w" width="360"/> </a>
# </div>
# <div class="content">
# <span class="category text-info"><a href="https://www.wmrt.org.uk/category/fundraising/" title="View all posts in Fundraising">Fundraising</a> </span>
# <h4 class="card-title">
# <a class="blog-item-title-link" href="https://www.wmrt.org.uk/2025/02/save-the-date-saturday-10-may-2025-the-wasdale-head-inn-supporting-wmrt/" rel="bookmark" title="Save the date – Saturday 10 May 2025 – The Wasdale Head Inn supporting WMRT">
# 														Save the date – Saturday 10 May 2025 – The Wasdale Head Inn supporting WMRT													</a>
# </h4>
# <p class="card-description">Incident25 in 2025 TypeAlert — Cragfast LocationUpper EskdaleWeatherDry, SunnyOther AgenciesCumbria PoliceTaggedCragfastSave The Date! Something BIG is about to happen! Be prepared for a day full of family fun with your favourite Wasdale Mountain Rescue Team!<a class="moretag" href="https://www.wmrt.org.uk/2025/02/save-the-date-saturday-10-may-2025-the-wasdale-head-inn-supporting-wmrt/"> Read more…</a></p>
# </div>
# </div>
# </div>
# <div class="col-md-4">
# <div class="card card-blog">
# <div class="card-image">
# <a href="https://www.wmrt.org.uk/2025/01/20475/" title="WMRT fundraising in Egremont and Whitehaven">
# <img alt="" class="attachment-hestia-blog size-hestia-blog wp-post-image" decoding="async" height="240" loading="lazy" sizes="auto, (max-width: 360px) 100vw, 360px" src="https://www.wmrt.org.uk/wp-content/uploads/2025/01/Egremont-360x240.jpg" srcset="https://www.wmrt.org.uk/wp-content/uploads/2025/01/Egremont-360x240.jpg 360w, https://www.wmrt.org.uk/wp-content/uploads/2025/01/Egremont-600x400.jpg 600w" width="360"/> </a>
# </div>
# <div class="content">
# <span class="category text-info"><a href="https://www.wmrt.org.uk/category/fundraising/" title="View all posts in Fundraising">Fundraising</a> </span>
# <h4 class="card-title">
# <a class="blog-item-title-link" href="https://www.wmrt.org.uk/2025/01/20475/" rel="bookmark" title="WMRT fundraising in Egremont and Whitehaven">
# 														WMRT fundraising in Egremont and Whitehaven													</a>
# </h4>
# <p class="card-description">Incident25 in 2025 TypeAlert — Cragfast LocationUpper EskdaleWeatherDry, SunnyOther AgenciesCumbria PoliceTaggedCragfast Members of the team were in Egremont on Saturday 7 December and in Whitehaven on Saturday 21 December for the annual fundraising event in<a class="moretag" href="https://www.wmrt.org.uk/2025/01/20475/"> Read more…</a></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer class="footer footer-black footer-big">
# <div class="container">
# <div class="content">
# <div class="row">
# <div class="col-md-4"><div class="widget widget_block" id="block-5"><div id="customPopup" style="display:none;">
# <div class="popup-overlay" onclick="closePopup()"></div>
# <div aria-labelledby="popupTitle" aria-modal="true" class="popup-content" role="dialog">
# <button aria-label="Close popup" class="close-btn" onclick="closePopup()">×</button>
# <h2 id="popupTitle">Come to the Rescue!</h2>
# <p>Join your local heroes for a fun-filled family day out on <strong>10th May</strong> – full of activities, demos, talent show, live music and more!</p>
# <a class="popup-cta" href="https://www.wmrt.org.uk/2025/03/come-to-the-rescue-family-fun-day-with-your-local-heroes-10th-may/" rel="noopener noreferrer" target="_blank">Learn More</a>
# </div>
# </div></div></div> </div>
# </div>
# <hr>
# <div class="hestia-bottom-footer-content"><ul class="footer-menu pull-left"><li class="page_item page-item-15550"><a href="https://www.wmrt.org.uk/50th-anniversary-book-mountain-rescue-in-wasdale/">50th Anniversary Book – Mountain Rescue In Wasdale</a></li>
# <li class="page_item page-item-648"><a href="https://www.wmrt.org.uk/about-us/">About Us</a></li>
# <li class="page_item page-item-1034"><a href="https://www.wmrt.org.uk/scafell-broad-stand/">Broad Stand – There is no easy route direct from Scafell to Scafell Pike!</a></li>
# <li class="page_item page-item-670"><a href="https://www.wmrt.org.uk/contact-us/">Contact Us</a></li>
# <li class="page_item page-item-13872"><a href="https://www.wmrt.org.uk/how-to-join-the-team/">How to Join Our Team</a></li>
# <li class="page_item page-item-15850 current_page_parent"><a href="https://www.wmrt.org.uk/news/">News</a></li>
# <li class="page_item page-item-1037"><a href="https://www.wmrt.org.uk/piers-gill-scafell-pike/">Piers Gill – Scafell Pike</a></li>
# <li class="page_item page-item-820"><a href="https://www.wmrt.org.uk/preparation-for-going-into-the-fells/">Preparation For Going Into The Fells</a></li>
# <li class="page_item page-item-1413"><a href="https://www.wmrt.org.uk/report-page/">Report Page</a></li>
# <li class="page_item page-item-339"><a href="https://www.wmrt.org.uk/rescue-map/">Rescue Map</a></li>
# <li class="page_item page-item-2054"><a href="https://www.wmrt.org.uk/donate-to-the-team/">Support Us</a></li>
# <li class="page_item page-item-16682"><a href="https://www.wmrt.org.uk/support-us/">Support Us</a></li>
# <li class="page_item page-item-18570"><a href="https://www.wmrt.org.uk/team-shop/">Team Shop</a></li>
# <li class="page_item page-item-16848"><a href="https://www.wmrt.org.uk/team-shop-item-safe/">Team Shop – Item Safe</a></li>
# <li class="page_item page-item-2046"><a href="https://www.wmrt.org.uk/terms-and-conditions/">Terms and Conditions</a></li>
# <li class="page_item page-item-2404"><a href="https://www.wmrt.org.uk/thank-you/">Thank You</a></li>
# <li class="page_item page-item-1277"><a href="https://www.wmrt.org.uk/the-easiest-way-up-scafell-pike/">The Easiest Way Up Scafell Pike (and Down Again!)</a></li>
# <li class="page_item page-item-10579"><a href="https://www.wmrt.org.uk/the-three-peaks/">The National Three Peaks</a></li>
# <li class="page_item page-item-203"><a href="https://www.wmrt.org.uk/want-to-join-the-team/">Want to Join the Team ?</a></li>
# <li class="page_item page-item-15812"><a href="https://www.wmrt.org.uk/">Wasdale Mountain Rescue Team</a></li>
# <li class="page_item page-item-67"><a href="https://www.wmrt.org.uk/supporters-club/">Supporters’ Club</a></li>
# <li class="page_item page-item-1453 page_item_has_children"><a href="https://www.wmrt.org.uk/in-memory/">In Memory</a></li>
# </ul>
# <div class="copyright pull-right">Hestia | Developed by <a href="https://themeisle.com" rel="nofollow">ThemeIsle</a></div></div> </hr></div>
# </footer>
# </div>
# <script>
#   function showPopup() {
#     document.getElementById('customPopup').style.display = 'block';
#   }
#
#   function closePopup() {
#     document.getElementById('customPopup').style.display = 'none';
#   }
#
#   window.addEventListener('load', function () {
#   if (!sessionStorage.getItem('popupShown')) {
#     setTimeout(function () {
#       showPopup();
#       sessionStorage.setItem('popupShown', 'true');
#     }, 2000);
#   }
# });
# </script><script id="wpo_min-footer-0-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var JQLBSettings = {"fitToScreen":"1","resizeSpeed":"400","displayDownloadLink":"1","navbarOnTop":"0","loopImages":"","resizeCenter":"","marginSize":"0","linkTarget":"_self","help":"","prevLinkTitle":"previous image","nextLinkTitle":"next image","prevLinkText":"\u00ab Previous","nextLinkText":"Next \u00bb","closeTitle":"close image gallery","image":"Image ","of":" of ","download":"Download","jqlb_overlay_opacity":"80","jqlb_overlay_color":"#000000","jqlb_overlay_close":"1","jqlb_border_width":"10","jqlb_border_color":"#ffffff","jqlb_border_radius":"0","jqlb_image_info_background_transparency":"100","jqlb_image_info_bg_color":"#ffffff","jqlb_image_info_text_color":"#000000","jqlb_image_info_text_fontsize":"10","jqlb_show_text_for_image":"1","jqlb_next_image_title":"next image","jqlb_previous_image_title":"previous image","jqlb_next_button_image":"https:\/\/www.wmrt.org.uk\/wp-content\/plugins\/wp-lightbox-2\/styles\/images\/next.gif","jqlb_previous_button_image":"https:\/\/www.wmrt.org.uk\/wp-content\/plugins\/wp-lightbox-2\/styles\/images\/prev.gif","jqlb_maximum_width":"","jqlb_maximum_height":"","jqlb_show_close_button":"1","jqlb_close_image_title":"close image gallery","jqlb_close_image_max_heght":"22","jqlb_image_for_close_lightbox":"https:\/\/www.wmrt.org.uk\/wp-content\/plugins\/wp-lightbox-2\/styles\/images\/closelabel.gif","jqlb_keyboard_navigation":"1","jqlb_popup_size_fix":"0"};
# /* ]]> */
# </script>
# <script defer="" id="wpo_min-footer-0-js" src="https://www.wmrt.org.uk/wp-content/cache/wpo-minify/1741724414/assets/wpo-minify-footer-cbd02043.min.js" type="text/javascript"></script>
# </body>
# </html>

# %%
extract_data = []
title = soup.find('h1').get_text()

table = soup.find('dl','dl-horizontal')
headings = table.find_all('dt')
details = table.find_all('dd')

rescue_info = soup.find(id="rescueinfo")
extract_data.append({'title': title})

# %%
matches = re.search(r"([0-9]{1,2})(?:st|nd|rd|th) ([a-zA-Z]{3} [0-9]{4})", title)
matches.group(1) + ' ' +  matches.group(2)
# Out:
# '18 Jan 2025'

# %%
table_dict = {'title':title}
for i in range(0,len(headings)):
    table_dict[headings[i].string] = details[i].get_text().replace('\xa0', ' ')

# %%
table_dict
# Out:
# {'title': 'Corridor Route, Scafell Pike – Sat 18th Jan 2025',
#  'Incident': '6 in 2025',
#  'Type': 'Full Callout — Cragfast',
#  'Location': 'Corridor Route, Scafell Pike',
#  'Weather': 'Clear, Cool, Dark',
#  'Tagged': 'Cragfast, Lost'}

# %%
if 'Type' in table_dict.keys():
    incident = table_dict['Type'].split(' — ')
    table_dict['Incident_Type'] = incident[0]
    table_dict['Incident_Cause'] = incident[1]

if 'Weather' in table_dict.keys():
    table_dict['Weather'] = table_dict['Weather'].split(', ')

if 'Tagged' in table_dict.keys():
    table_dict['Tagged'] = table_dict['Tagged'].split(', ')

# %%
#for analysis and understanding purposes
rel_tags = soup.find_all('a',rel='tag')

rel_tags_clean = [x.string.replace('\xa0', ' ') for x in rel_tags]

# %%
articles = soup.find_all('p')

# %%
matches = re.search("started at", articles)
matches
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 matches = re.search("started at", articles)
#       2 matches
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\re\__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object, got 'ResultSet'

# %%
x = [p.get_text()=='\xa0' for p in articles]

# %%
x.index(True)
# Out:
# 5

# %%
article = ""
for i in range(1,x.index(True)):
    article = article + articles[i].get_text() + ' '

# %%
information = articles[x.index(True) + 1].get_text()
information
# Out:
# ' Incident started at 18:12 and ended at 22:42 making 4.5 hrs in total. There were 20 Wasdale team members involved and the incident occured at NY 21700 08600. Total rescuer hours: 90'

# %%
matches = re.search(r"started at ([0-9]{2}:[0-9]{2})", information) 
if matches:
    start_time = matches.group(1)
    print(start_time)
matches = re.search(r"ended at ([0-9]{2}:[0-9]{2})", information) 
if matches:
    end_time = matches.group(1)
    print(end_time)
matches = re.search(r"(\d+\.?\d*) hrs", information)
if matches:
    hrs = matches.group(1)
    print(hrs)
matches = re.search(r"(\d+) Wasdale", information) 
if matches:
    staff = matches.group(1)
    print(staff)
matches = re.search(r"(NY[ \d]+)", information) 
if matches:
    location = matches.group(1)
    print(location)
matches = re.search(r"Total rescuer hours: (\d+\.?\d*)", information)
if matches:
    total_hrs = matches.group(1)
    print(total_hrs)
# Out:
# 18:12
# 22:42
# 4.5
# 20
# NY 21700 08600
# 90

# %%
matches = re.search(r"(\d+) Wasdale", information) 
if matches:
    staff = matches.group(1)
    print(staff)
# Out:
# 20

# %%
matches = re.search(r"\d+", 'making 4.5 hrs in total') 

print(matches)
if matches:
    hrs = matches.group(1)
    print(hrs)
# Out:
# <re.Match object; span=(7, 8), match='4'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[116], line 5
#       3 print(matches)
#       4 if matches:
# ----> 5     hrs = matches.group(1)
#       6     print(hrs)
#
# IndexError: no such group

# %%
matches

# %%
import time
time.strptime(start_time,"%H:%M")
# Out:
# time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=18, tm_min=12, tm_sec=0, tm_wday=0, tm_yday=1, tm_isdst=-1)

# %%
matches = re.search(r"started at ([0-9]{2}:[0-9]{2}) and ended at ([0-9]{2}:[0-9]{3}) making (4.5) hrs", information)
start_time = matches.group(1)
start_time
end_time = matches.group(2)
end_time
hrs = matches.group(3)
hrs

# %%
end_time
# Out:
# '22:42'
